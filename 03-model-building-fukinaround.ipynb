# %% [markdown]
# # Model Building

# %% [markdown]
# ## Data Pipeline
# Tensorflow works best when data is organized into an input pipeline.  These pipelines help organize, batch, shuffle, and serve your data to CPU/GPU during learning.   The [`tf.data`](https://www.tensorflow.org/api_docs/python/tf/data) module API assists with this.
#
# The main structure is the `tf.data.Dataset` object.  It loads data from disk, applies optimized transformations, creates batches, and sends it to CPU/GPU.
#
# [Google blog post on tf.data.Datasets](https://developers.googleblog.com/2017/09/introducing-tensorflow-datasets.html)
# [Tutorial on tf.data](https://www.tensorflow.org/guide/data)
# [Advanced guide on tf.data](https://www.tensorflow.org/guide/data)
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt 
import seaborn as sns

import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.layers as layers 

from PIL import Image 

print(tf.__version__)
# Out:
# 2.1.0

# %% [markdown]
# ### Read X, y from files
# Preprocessing is done in `munge-data.ipynb`

# %%
y_train_bin = np.loadtxt('data/munged/y_train.csv', delimiter=',') 
y_val_bin = np.loadtxt('data/munged/y_val.csv', delimiter=',') 
y_test_bin = np.loadtxt('data/munged/y_test.csv', delimiter=',')

# %%
X_train = np.loadtxt('data/munged/X_train.csv', dtype=str)
X_val = np.loadtxt('data/munged/X_val.csv', dtype=str)
X_test = np.loadtxt('data/munged/X_test.csv', dtype=str)

# %% [markdown]
# Verify data shapes

# %%
y_train_bin.shape, y_val_bin.shape, y_test_bin.shape
# Out:
# ((691, 18), (77, 18), (41, 18))

# %%
len(X_train), len(X_val), len(X_test)
# Out:
# (691, 77, 41)

# %% [markdown]
# Read labels from file

# %%
import json 

with open('data/munged/labels.json') as json_file:
    type_encoding = json.load(json_file)

# convert string keys to ints 
type_encoding = {int(k):v for k, v in type_encoding.items()}

type_encoding
# Out:
# {0: 'Bug',
#  1: 'Dark',
#  2: 'Dragon',
#  3: 'Electric',
#  4: 'Fairy',
#  5: 'Fighting',
#  6: 'Fire',
#  7: 'Flying',
#  8: 'Ghost',
#  9: 'Grass',
#  10: 'Ground',
#  11: 'Ice',
#  12: 'Normal',
#  13: 'Poison',
#  14: 'Psychic',
#  15: 'Rock',
#  16: 'Steel',
#  17: 'Water'}

# %% [markdown]
# ### Build Pipeline
#
# We are ready to build the tf.data.Dataset.  In these functions, you _must_ use tf API and operate with tensor objects.

# %%
from importlib import reload 
import utils 
reload(utils)
# Out:
# <module 'utils' from 'C:\\Users\\rshn\\Developer\\kaggle\\pokemon-types\\utils.py'>

# %%
BATCH_SIZE = 32 
AUTOTUNE = tf.data.experimental.AUTOTUNE  # Adapt preprocessing and prefetching dynamically
SHUFFLE_BUFFER_SIZE = 8                   # Shuffle the training data by a chunck of this many observations

# %%
train_augment_ds = utils.create_dataset(X_train, y_train_bin, SHUFFLE_BUFFER_SIZE, AUTOTUNE, BATCH_SIZE, augment=True)
train_ds = utils.create_dataset(X_train, y_train_bin, SHUFFLE_BUFFER_SIZE, AUTOTUNE, BATCH_SIZE, augment=False)
val_ds = utils.create_dataset(X_val, y_val_bin, SHUFFLE_BUFFER_SIZE, AUTOTUNE, BATCH_SIZE, augment=False)
test_ds = utils.create_dataset(X_test, y_test_bin, SHUFFLE_BUFFER_SIZE, AUTOTUNE, BATCH_SIZE, augment=False)

# %% [markdown]
# ## Examine the `tf.data.Dataset`

# %% [markdown]
# Shapes of items in dataset:
# ```
# features:  (BATCH SIZE, IMG_HEIGHT, IMG_WIDTH, CHANNELS)
# label:     (BATCH_SIZE, N_LABELS)
#
# ```

# %%
for f, l in train_ds.take(1):
    print("Shape of features array:", f.numpy().shape)
    print("Shape of labels array:", l.numpy().shape)
    
    print("\nPlot one of the images from the first batch")
    plt.imshow(f[0])
    plt.title(str(l.numpy()[0]), size=15)
    plt.axis(False)
# Out:
# Shape of features array: (32, 120, 120, 3)
# Shape of labels array: (32, 18)
#
# Plot one of the images from the first batch

# %% [markdown]
# Use .take(n) to gave `n` batches.  We set batch_size to 32.

# %% [markdown]
# ## Concatenating augmented dataset and regular dataset

# %%
train_ds = train_ds.concatenate(train_augment_ds)

# %% [markdown]
# Print samples of training images

# %%
fig, axes = plt.subplots(3, 9, figsize=(30, 10))
axes = axes.reshape(-1)

fig.suptitle('Training image set (with augmentation)', fontsize=32)

for idx, (f, l) in enumerate(train_ds.take(3*9)):
    axes[idx].imshow(f[0])
    axes[idx].set_title(str(l.numpy()[0]), size=7)
    axes[idx].axis(False)

# %% [markdown]
# # Model Building

# %%
img = Image.open('data/bulbasaur.png')
IMG_HEIGHT, IMG_WIDTH = img.height, img.width
CHANNELS = 3  
N_LABELS = 18

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization   

model = tf.keras.Sequential([
    Conv2D(16, (3, 3), activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH, CHANNELS)), 
    BatchNormalization(), 
    MaxPooling2D((2, 2)),   
    
    Conv2D(32, (3, 3), activation='relu'), 
    BatchNormalization(), 
    MaxPooling2D((2, 2)), 
    
    Conv2D(64, (3, 3), activation='relu'), 
    BatchNormalization(), 
    MaxPooling2D((2, 2)), 

    Conv2D(128, (3, 3), activation='relu'), 
    BatchNormalization(), 
    MaxPooling2D((2, 2)), 
   
    Conv2D(256, (3, 3), activation='relu'), 
    BatchNormalization(), 
    MaxPooling2D((2, 2)),   
    
    Flatten(), 
    Dense(128, activation='relu'), 
    Dense(N_LABELS), 
])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 118, 118, 16)      448
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 118, 118, 16)      64
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 59, 59, 16)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 57, 57, 32)        4640
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 57, 57, 32)        128
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 26, 26, 64)        18496
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 26, 26, 64)        256
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 11, 11, 128)       73856
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 11, 11, 128)       512
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 5, 5, 128)         0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 3, 3, 256)         295168
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 3, 3, 256)         1024
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_7 (Dense)              (None, 18)                2322
# =================================================================
# Total params: 429,810
# Trainable params: 428,818
# Non-trainable params: 992
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), 
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True), 
              metrics=[tf.keras.metrics.TopKCategoricalAccuracy(k=2)])

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',patience=15, verbose=0
)

callbacks = [early_stopping]

# %% [markdown]
# ### Train model

# %%
history = model.fit(train_ds, 
                   epochs=500, 
                   validation_data=val_ds, 
                   callbacks=callbacks, 
                   verbose=1)
# Out:
# Train for 44 steps, validate for 3 steps
# Epoch 1/500
# 44/44 [==============================] - 2s 41ms/step - loss: 0.5444 - top_k_categorical_accuracy: 0.1599 - val_loss: 0.7208 - val_top_k_categorical_accuracy: 0.1299
# Epoch 2/500
# 44/44 [==============================] - 1s 15ms/step - loss: 0.2939 - top_k_categorical_accuracy: 0.2446 - val_loss: 0.7579 - val_top_k_categorical_accuracy: 0.1299
# Epoch 3/500
# 44/44 [==============================] - 1s 16ms/step - loss: 0.2547 - top_k_categorical_accuracy: 0.3567 - val_loss: 0.7876 - val_top_k_categorical_accuracy: 0.1169
# Epoch 4/500
# 44/44 [==============================] - 1s 16ms/step - loss: 0.2304 - top_k_categorical_accuracy: 0.4631 - val_loss: 0.7573 - val_top_k_categorical_accuracy: 0.1039
# Epoch 5/500
# 44/44 [==============================] - 1s 16ms/step - loss: 0.2081 - top_k_categorical_accuracy: 0.5789 - val_loss: 0.6930 - val_top_k_categorical_accuracy: 0.0909
# Epoch 6/500
# 44/44 [==============================] - 1s 16ms/step - loss: 0.1861 - top_k_categorical_accuracy: 0.6758 - val_loss: 0.6098 - val_top_k_categorical_accuracy: 0.1429
# Epoch 7/500
# 44/44 [==============================] - 1s 16ms/step - loss: 0.1638 - top_k_categorical_accuracy: 0.7735 - val_loss: 0.5221 - val_top_k_categorical_accuracy: 0.1169
# Epoch 8/500
# 44/44 [==============================] - 1s 16ms/step - loss: 0.1417 - top_k_categorical_accuracy: 0.8452 - val_loss: 0.4564 - val_top_k_categorical_accuracy: 0.1558
# Epoch 9/500
# 44/44 [==============================] - 1s 16ms/step - loss: 0.1202 - top_k_categorical_accuracy: 0.9009 - val_loss: 0.3917 - val_top_k_categorical_accuracy: 0.1688
# Epoch 10/500
# 44/44 [==============================] - 1s 16ms/step - loss: 0.1000 - top_k_categorical_accuracy: 0.9472 - val_loss: 0.3453 - val_top_k_categorical_accuracy: 0.1948
# Epoch 11/500
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0817 - top_k_categorical_accuracy: 0.9660 - val_loss: 0.3223 - val_top_k_categorical_accuracy: 0.2208
# Epoch 12/500
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0663 - top_k_categorical_accuracy: 0.9848 - val_loss: 0.3140 - val_top_k_categorical_accuracy: 0.2338
# Epoch 13/500
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0535 - top_k_categorical_accuracy: 0.9899 - val_loss: 0.3092 - val_top_k_categorical_accuracy: 0.2857
# Epoch 14/500
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0426 - top_k_categorical_accuracy: 0.9942 - val_loss: 0.3144 - val_top_k_categorical_accuracy: 0.2468
# Epoch 15/500
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0354 - top_k_categorical_accuracy: 0.9986 - val_loss: 0.3150 - val_top_k_categorical_accuracy: 0.2987
# Epoch 16/500
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0291 - top_k_categorical_accuracy: 0.9986 - val_loss: 0.3338 - val_top_k_categorical_accuracy: 0.2857
# Epoch 17/500
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0243 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.3410 - val_top_k_categorical_accuracy: 0.2597
# Epoch 18/500
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0204 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.3530 - val_top_k_categorical_accuracy: 0.2338
# Epoch 19/500
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0174 - top_k_categorical_accuracy: 0.9993 - val_loss: 0.3599 - val_top_k_categorical_accuracy: 0.2468
# Epoch 20/500
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0150 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.3629 - val_top_k_categorical_accuracy: 0.2338
# Epoch 21/500
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0130 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.3937 - val_top_k_categorical_accuracy: 0.2468
# Epoch 22/500
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0110 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.3925 - val_top_k_categorical_accuracy: 0.2338
# Epoch 23/500
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0097 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.4064 - val_top_k_categorical_accuracy: 0.2338
# Epoch 24/500
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0083 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.4204 - val_top_k_categorical_accuracy: 0.2468
# Epoch 25/500
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0076 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.4187 - val_top_k_categorical_accuracy: 0.2338
# Epoch 26/500
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0065 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.4358 - val_top_k_categorical_accuracy: 0.2338
# Epoch 27/500
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0060 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.4436 - val_top_k_categorical_accuracy: 0.2208
# Epoch 28/500
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0054 - top_k_categorical_accuracy: 1.0000 - val_loss: 0.4385 - val_top_k_categorical_accuracy: 0.2338

# %% [markdown]
# ### Plot the learning curves

# %%
keys = list(history.history.keys())

fig, axes = plt.subplots(1, 2, figsize=(10, 5))
axes.reshape(-1, 1)


for idx, ax in enumerate(axes): 

    axes[idx].plot(history.history[keys[idx]], label=keys[idx])
    axes[idx].plot(history.history["val_" + keys[idx]], label = "val_" + keys[idx])
    axes[idx].set_xlabel('Epoch')
    axes[idx].set_ylabel(keys[idx])
    axes[idx].legend()
    axes[idx].grid(True)

test_loss, test_acc = model.evaluate(test_ds, verbose=2); 
print("\n\nLoss on test set {:.3},  Categorical accuracy on test set {:.3f}".format(test_loss, test_acc))
# Out:
# 2/2 - 0s - loss: 0.4304 - top_k_categorical_accuracy: 0.2683
#
#
# Loss on test set 0.43,  Categorical accuracy on test set 0.268

# %% [markdown]
# ## Visualize results

# %%
# Training data 
utils.plot_prediction_grid(model, train_ds, (4, 3), True)
plt.tight_layout()

# %%
## Test on test_set 
utils.plot_prediction_grid(model, test_ds, (4, 3), True)
plt.tight_layout()

# %% [markdown]
# ---
# ---
# ---
#
# ## Save model

# %%
# from datetime import datetime
# import os 

# date_time = datetime.now().strftime("%Y%m%d-%H%M%S")
# dirname = "saved_models/" + date_time + "-aug-bce"

# os.mkdir(dirname)
# model.save(dirname)

# %% [markdown]
# ### load model and test

# %%
# new_model = tf.keras.models.load_model('saved_models/20200627-133409-baseline')

# ## Test on test_set 
# utils.plot_prediction_grid(new_model, test_ds, (5, 5), True)
