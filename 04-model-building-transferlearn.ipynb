# %% [markdown]
# # Model Building

# %% [markdown]
# ## Data Pipeline
# Tensorflow works best when data is organized into an input pipeline.  These pipelines help organize, batch, shuffle, and serve your data to CPU/GPU during learning.   The [`tf.data`](https://www.tensorflow.org/api_docs/python/tf/data) module API assists with this.
#
# The main structure is the `tf.data.Dataset` object.  It loads data from disk, applies optimized transformations, creates batches, and sends it to CPU/GPU.
#
# [Google blog post on tf.data.Datasets](https://developers.googleblog.com/2017/09/introducing-tensorflow-datasets.html)
# [Tutorial on tf.data](https://www.tensorflow.org/guide/data)
# [Advanced guide on tf.data](https://www.tensorflow.org/guide/data)
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt 
import seaborn as sns

import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.layers as layers 

from PIL import Image 

print(tf.__version__)
# Out:
# 2.1.0

# %% [markdown]
# ### Read X, y from files
# Preprocessing is done in `munge-data.ipynb`

# %%
y_train_bin = np.loadtxt('data/munged/y_train.csv', delimiter=',') 
y_val_bin = np.loadtxt('data/munged/y_val.csv', delimiter=',') 
y_test_bin = np.loadtxt('data/munged/y_test.csv', delimiter=',')

# %%
X_train = np.loadtxt('data/munged/X_train.csv', dtype=str)
X_val = np.loadtxt('data/munged/X_val.csv', dtype=str)
X_test = np.loadtxt('data/munged/X_test.csv', dtype=str)

# %% [markdown]
# Verify data shapes

# %%
y_train_bin.shape, y_val_bin.shape, y_test_bin.shape
# Out:
# ((691, 18), (77, 18), (41, 18))

# %%
len(X_train), len(X_val), len(X_test)
# Out:
# (691, 77, 41)

# %% [markdown]
# Read labels from file

# %%
import json 

with open('data/munged/labels.json') as json_file:
    type_encoding = json.load(json_file)

# convert string keys to ints 
type_encoding = {int(k):v for k, v in type_encoding.items()}

type_encoding
# Out:
# {0: 'Bug',
#  1: 'Dark',
#  2: 'Dragon',
#  3: 'Electric',
#  4: 'Fairy',
#  5: 'Fighting',
#  6: 'Fire',
#  7: 'Flying',
#  8: 'Ghost',
#  9: 'Grass',
#  10: 'Ground',
#  11: 'Ice',
#  12: 'Normal',
#  13: 'Poison',
#  14: 'Psychic',
#  15: 'Rock',
#  16: 'Steel',
#  17: 'Water'}

# %% [markdown]
# ### Build Pipeline
#
# We are ready to build the tf.data.Dataset.  In these functions, you _must_ use tf API and operate with tensor objects.

# %%
from importlib import reload 
import utils 
reload(utils)
# Out:
# <module 'utils' from 'C:\\Users\\rshn\\Developer\\kaggle\\pokemon-types\\utils.py'>

# %%
BATCH_SIZE = 32 
AUTOTUNE = tf.data.experimental.AUTOTUNE  # Adapt preprocessing and prefetching dynamically
SHUFFLE_BUFFER_SIZE = 8                   # Shuffle the training data by a chunck of this many observations

# %%
train_augment_ds = utils.create_dataset_mobilenet(X_train, y_train_bin, SHUFFLE_BUFFER_SIZE, AUTOTUNE, BATCH_SIZE, augment=True)
train_ds = utils.create_dataset_mobilenet(X_train, y_train_bin, SHUFFLE_BUFFER_SIZE, AUTOTUNE, BATCH_SIZE, augment=False)
val_ds = utils.create_dataset_mobilenet(X_val, y_val_bin, SHUFFLE_BUFFER_SIZE, AUTOTUNE, BATCH_SIZE, augment=False)
test_ds = utils.create_dataset_mobilenet(X_test, y_test_bin, SHUFFLE_BUFFER_SIZE, AUTOTUNE, BATCH_SIZE, augment=False)

# %% [markdown]
# ## Examine the `tf.data.Dataset`

# %% [markdown]
# Shapes of items in dataset:
# ```
# features:  (BATCH SIZE, IMG_HEIGHT, IMG_WIDTH, CHANNELS)
# label:     (BATCH_SIZE, N_LABELS)
#
# ```

# %%
for f, l in train_ds.take(1):
    print("Shape of features array:", f.numpy().shape)
    print("Shape of labels array:", l.numpy().shape)
    
    print("\nPlot one of the images from the first batch")
    plt.imshow(f[0])
    plt.title(str(l.numpy()[0]), size=15)
    plt.axis(False)
# Out:
# Shape of features array: (32, 160, 160, 3)
# Shape of labels array: (32, 18)
#
# Plot one of the images from the first batch

# %% [markdown]
# Use .take(n) to gave `n` batches.  We set batch_size to 32.

# %% [markdown]
# ## Concatenating augmented dataset and regular dataset

# %%
train_ds = train_ds.concatenate(train_augment_ds)

# %% [markdown]
# Print samples of training images

# %%
fig, axes = plt.subplots(3, 9, figsize=(30, 10))
axes = axes.reshape(-1)

fig.suptitle('Training image set (with augmentation)', fontsize=32)

for idx, (f, l) in enumerate(train_ds.take(3*9)):
    axes[idx].imshow(f[0])
    axes[idx].set_title(str(l.numpy()[0]), size=7)
    axes[idx].axis(False)

# %% [markdown]
# # Model Building
#
# Transfer learn MobileNetV2

# %%
IMG_HEIGHT, IMG_WIDTH = 160, 160
CHANNELS = 3  
N_LABELS = 18

# %%
IMG_SHAPE = (160, 160, 3)

# Create the base model from the pre-trained model MobileNet V2
base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')

# %%
base_model.trainable = False

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
prediction_layer = tf.keras.layers.Dense(N_LABELS)

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization   

model = tf.keras.Sequential([
    base_model,
    global_average_layer,
    Dense(128, activation='relu'), 
    Dropout(0.2), 
    Dense(N_LABELS)
])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_160 (Model) (None, 5, 5, 1280)        2257984
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 1280)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               163968
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 18)                2322
# =================================================================
# Total params: 2,424,274
# Trainable params: 166,290
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), 
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True), 
              metrics=[tf.keras.metrics.TopKCategoricalAccuracy(k=2)])

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',patience=15, verbose=0
)

callbacks = [early_stopping]

# %% [markdown]
# ### Train model

# %%
history = model.fit(train_ds, 
                   epochs=500, 
                   validation_data=val_ds, 
                   callbacks=callbacks, 
                   verbose=1)
# Out:
# Train for 44 steps, validate for 3 steps
# Epoch 1/500
# 44/44 [==============================] - 5s 109ms/step - loss: 0.5020 - top_k_categorical_accuracy: 0.1237 - val_loss: 0.3270 - val_top_k_categorical_accuracy: 0.0519
# Epoch 2/500
# 44/44 [==============================] - 1s 33ms/step - loss: 0.3241 - top_k_categorical_accuracy: 0.1411 - val_loss: 0.3144 - val_top_k_categorical_accuracy: 0.1039
# Epoch 3/500
# 44/44 [==============================] - 1s 32ms/step - loss: 0.3075 - top_k_categorical_accuracy: 0.1744 - val_loss: 0.3077 - val_top_k_categorical_accuracy: 0.1299
# Epoch 4/500
# 44/44 [==============================] - 1s 33ms/step - loss: 0.3031 - top_k_categorical_accuracy: 0.1643 - val_loss: 0.3163 - val_top_k_categorical_accuracy: 0.1169
# Epoch 5/500
# 44/44 [==============================] - 1s 33ms/step - loss: 0.2952 - top_k_categorical_accuracy: 0.2026 - val_loss: 0.3118 - val_top_k_categorical_accuracy: 0.1299
# Epoch 6/500
# 44/44 [==============================] - 1s 33ms/step - loss: 0.2877 - top_k_categorical_accuracy: 0.2069 - val_loss: 0.3088 - val_top_k_categorical_accuracy: 0.1688
# Epoch 7/500
# 44/44 [==============================] - 1s 33ms/step - loss: 0.2793 - top_k_categorical_accuracy: 0.2569 - val_loss: 0.3066 - val_top_k_categorical_accuracy: 0.1688
# Epoch 8/500
# 44/44 [==============================] - 1s 33ms/step - loss: 0.2755 - top_k_categorical_accuracy: 0.2569 - val_loss: 0.3059 - val_top_k_categorical_accuracy: 0.1688
# Epoch 9/500
# 44/44 [==============================] - 1s 32ms/step - loss: 0.2671 - top_k_categorical_accuracy: 0.3126 - val_loss: 0.3073 - val_top_k_categorical_accuracy: 0.1948
# Epoch 10/500
# 44/44 [==============================] - 1s 32ms/step - loss: 0.2617 - top_k_categorical_accuracy: 0.3155 - val_loss: 0.3034 - val_top_k_categorical_accuracy: 0.1688
# Epoch 11/500
# 44/44 [==============================] - 1s 32ms/step - loss: 0.2559 - top_k_categorical_accuracy: 0.3531 - val_loss: 0.3071 - val_top_k_categorical_accuracy: 0.1818
# Epoch 12/500
# 44/44 [==============================] - 1s 33ms/step - loss: 0.2511 - top_k_categorical_accuracy: 0.3647 - val_loss: 0.3111 - val_top_k_categorical_accuracy: 0.2078
# Epoch 13/500
# 44/44 [==============================] - 1s 33ms/step - loss: 0.2451 - top_k_categorical_accuracy: 0.3973 - val_loss: 0.3101 - val_top_k_categorical_accuracy: 0.1818
# Epoch 14/500
# 44/44 [==============================] - 1s 33ms/step - loss: 0.2429 - top_k_categorical_accuracy: 0.4276 - val_loss: 0.3061 - val_top_k_categorical_accuracy: 0.1948
# Epoch 15/500
# 44/44 [==============================] - 1s 33ms/step - loss: 0.2379 - top_k_categorical_accuracy: 0.4132 - val_loss: 0.3160 - val_top_k_categorical_accuracy: 0.2208
# Epoch 16/500
# 44/44 [==============================] - 1s 34ms/step - loss: 0.2344 - top_k_categorical_accuracy: 0.4559 - val_loss: 0.3023 - val_top_k_categorical_accuracy: 0.2078
# Epoch 17/500
# 44/44 [==============================] - 1s 32ms/step - loss: 0.2292 - top_k_categorical_accuracy: 0.4631 - val_loss: 0.3090 - val_top_k_categorical_accuracy: 0.1818
# Epoch 18/500
# 44/44 [==============================] - 1s 33ms/step - loss: 0.2247 - top_k_categorical_accuracy: 0.4848 - val_loss: 0.3090 - val_top_k_categorical_accuracy: 0.1948
# Epoch 19/500
# 44/44 [==============================] - 1s 33ms/step - loss: 0.2186 - top_k_categorical_accuracy: 0.5116 - val_loss: 0.3109 - val_top_k_categorical_accuracy: 0.1818
# Epoch 20/500
# 44/44 [==============================] - 1s 33ms/step - loss: 0.2169 - top_k_categorical_accuracy: 0.5282 - val_loss: 0.3139 - val_top_k_categorical_accuracy: 0.2078
# Epoch 21/500
# 44/44 [==============================] - 1s 33ms/step - loss: 0.2118 - top_k_categorical_accuracy: 0.5355 - val_loss: 0.3178 - val_top_k_categorical_accuracy: 0.1948
# Epoch 22/500
# 44/44 [==============================] - 1s 33ms/step - loss: 0.2076 - top_k_categorical_accuracy: 0.5550 - val_loss: 0.3181 - val_top_k_categorical_accuracy: 0.1818
# Epoch 23/500
# 44/44 [==============================] - 1s 33ms/step - loss: 0.2070 - top_k_categorical_accuracy: 0.5579 - val_loss: 0.3217 - val_top_k_categorical_accuracy: 0.1818
# Epoch 24/500
# 44/44 [==============================] - 1s 33ms/step - loss: 0.2002 - top_k_categorical_accuracy: 0.5615 - val_loss: 0.3204 - val_top_k_categorical_accuracy: 0.2078
# Epoch 25/500
# 44/44 [==============================] - 1s 33ms/step - loss: 0.1948 - top_k_categorical_accuracy: 0.6129 - val_loss: 0.3270 - val_top_k_categorical_accuracy: 0.1948
# Epoch 26/500
# 44/44 [==============================] - 1s 33ms/step - loss: 0.1931 - top_k_categorical_accuracy: 0.6020 - val_loss: 0.3248 - val_top_k_categorical_accuracy: 0.2338
# Epoch 27/500
# 44/44 [==============================] - 1s 33ms/step - loss: 0.1912 - top_k_categorical_accuracy: 0.6216 - val_loss: 0.3252 - val_top_k_categorical_accuracy: 0.2468
# Epoch 28/500
# 44/44 [==============================] - 1s 34ms/step - loss: 0.1887 - top_k_categorical_accuracy: 0.6288 - val_loss: 0.3245 - val_top_k_categorical_accuracy: 0.2468
# Epoch 29/500
# 44/44 [==============================] - 1s 32ms/step - loss: 0.1841 - top_k_categorical_accuracy: 0.6505 - val_loss: 0.3335 - val_top_k_categorical_accuracy: 0.2338
# Epoch 30/500
# 44/44 [==============================] - 1s 32ms/step - loss: 0.1811 - top_k_categorical_accuracy: 0.6570 - val_loss: 0.3278 - val_top_k_categorical_accuracy: 0.2468
# Epoch 31/500
# 44/44 [==============================] - 1s 32ms/step - loss: 0.1791 - top_k_categorical_accuracy: 0.6628 - val_loss: 0.3224 - val_top_k_categorical_accuracy: 0.2597

# %% [markdown]
# ### Plot the learning curves

# %%
keys = list(history.history.keys())

fig, axes = plt.subplots(1, 2, figsize=(10, 5))
axes.reshape(-1, 1)


for idx, ax in enumerate(axes): 

    axes[idx].plot(history.history[keys[idx]], label=keys[idx])
    axes[idx].plot(history.history["val_" + keys[idx]], label = "val_" + keys[idx])
    axes[idx].set_xlabel('Epoch')
    axes[idx].set_ylabel(keys[idx])
    axes[idx].legend()
    axes[idx].grid(True)

test_loss, test_acc = model.evaluate(test_ds, verbose=2); 
print("\n\nLoss on test set {:.3},  Categorical accuracy on test set {:.3f}".format(test_loss, test_acc))
# Out:
# 2/2 - 0s - loss: 0.2997 - top_k_categorical_accuracy: 0.1220
#
#
# Loss on test set 0.3,  Categorical accuracy on test set 0.122

# %% [markdown]
# ## Visualize results

# %%
# Training data 
utils.plot_prediction_grid(model, train_ds, (4, 3), True)
plt.tight_layout()

# %%
## Test on test_set 
utils.plot_prediction_grid(model, test_ds, (4, 3), True)
plt.tight_layout()

# %% [markdown]
# ---
# ---
# ---
#
# ## Save model

# %%
from datetime import datetime
import os 

date_time = datetime.now().strftime("%Y%m%d-%H%M%S")
dirname = "saved_models/" + date_time + "-aug-bce-mobilenet"

os.mkdir(dirname)
model.save(dirname)
# Out:
# WARNING:tensorflow:From C:\Users\rshn\Anaconda3\envs\tf2-gpu\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: saved_models/20200715-115531-aug-bce-mobilenet\assets

# %% [markdown]
# ### load model and test

# %%
# new_model = tf.keras.models.load_model('saved_models/20200627-133409-baseline')

# ## Test on test_set 
# utils.plot_prediction_grid(new_model, test_ds, (5, 5), True)
