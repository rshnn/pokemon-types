# %% [markdown]
# # Pokemon Type Prediction
#
# > Gotta batch 'em all!
#
# ![header](images/poke-header.jpg)

# %%
import matplotlib.pyplot as plt 
from PIL import Image

# %%
fig, axes = plt.subplots(2, 2, figsize=(7, 7))
axes = axes.reshape(-1)


axes[0].imshow(Image.open('data/bulbasaur.png'))
axes[1].imshow(Image.open('data/geodude.png'))
axes[2].imshow(Image.open('data/vulpix.png'))
axes[3].imshow(Image.open('data/zapdos.png'))

for ax in axes:
    ax.axis(False)
    
plt.tight_layout()

# %%
import pandas as pd

df = pd.read_csv('pokemon.csv')
df.head()
# Out:
#          Name  Type1   Type2
# 0   bulbasaur  Grass  Poison
# 1     ivysaur  Grass  Poison
# 2    venusaur  Grass  Poison
# 3  charmander   Fire     NaN
# 4  charmeleon   Fire     NaN
